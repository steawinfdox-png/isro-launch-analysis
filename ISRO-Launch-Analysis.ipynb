# %%
#https://docs.google.com/spreadsheets/d/1gEADrXaokIpnIV90T1-3dkIiBNi5fH_6Y30d42SevOw/edit?gid=583886548#gid=583886548
#https://docs.google.com/spreadsheets/d/1gEADrXaokIpnIV90T1-3dkIiBNi5fH_6Y30d42SevOw/edit?usp=sharing
import pandas as pd
sheet_id = '1gEADrXaokIpnIV90T1-3dkIiBNi5fH_6Y30d42SevOw'
xls = pd.ExcelFile(f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=xlsx")
df = pd.read_excel(xls, 'ISRO mission launches', header = 0)
df
# Out:
#      SL No                      Launch Date Launch Vehicle  \
# 0      125                        Aditya-L1     2023-09-02
# 1      124                    Chandrayaan-3     2023-07-14
# 2      123                           NVS-01     2023-05-29
# 3      122                           EOS-07     2023-02-10
# 4      121                          Thybolt     2022-11-26
# ..     ...                              ...            ...
# 120      5           Rohini Satellite RS-D1     1981-05-31
# 121      4            Rohini Satellite RS-1     1980-07-18
# 122      3  Rohini Technology Payload (RTP)     1979-08-10
# 123      2                       Bhaskara-I     1979-06-07
# 124      1                        Aryabhata     1975-04-19
#
#                     Launch Vehicle.1             Orbit Type  \
# 0         PSLV-C57/Aditya-L1 Mission                  Lunar
# 1    LVM3 M4 / Chandrayaan-3 Mission                  Lunar
# 2            GSLV-F12/NVS-01 Mission                    NaN
# 3             SSLV-D2/EOS-07 Mission                    NaN
# 4            PSLV-C54/EOS-06 Mission                    NaN
# ..                               ...                    ...
# 120                          SLV-3D1  LEO (Low Earth Orbit)
# 121                          SLV-3E2                    NaN
# 122                          SLV-3E1                    NaN
# 123                   C-1Intercosmos  LEO (Low Earth Orbit)
# 124                  C-1 Intercosmos                    NaN
#
#                          Application              Remarks
# 0              Planetary Observation    Launch successful
# 1              Planetary Observation    Launch successful
# 2                         Navigation    Launch successful
# 3                  Earth Observation    Launch successful
# 4                  Earth Observation    Launch successful
# ..                               ...                  ...
# 120                Earth Observation    Launch successful
# 121                              NaN    Launch successful
# 122                              NaN  Launch unsuccessful
# 123  Earth Observation, Experimental    Launch successful
# 124                     Experimental    Launch successful
#
# [125 rows x 7 columns]

# %%
df['Mission Name'] = df['Launch Date']
df['Launch Date'] = df['Launch Vehicle']
df['Launch Vehicle'] = df['Launch Vehicle.1']
df = df.drop(columns=['Launch Vehicle.1'])
df
# Out:
#      SL No Launch Date                   Launch Vehicle  \
# 0      125  2023-09-02       PSLV-C57/Aditya-L1 Mission
# 1      124  2023-07-14  LVM3 M4 / Chandrayaan-3 Mission
# 2      123  2023-05-29          GSLV-F12/NVS-01 Mission
# 3      122  2023-02-10           SSLV-D2/EOS-07 Mission
# 4      121  2022-11-26          PSLV-C54/EOS-06 Mission
# ..     ...         ...                              ...
# 120      5  1981-05-31                          SLV-3D1
# 121      4  1980-07-18                          SLV-3E2
# 122      3  1979-08-10                          SLV-3E1
# 123      2  1979-06-07                   C-1Intercosmos
# 124      1  1975-04-19                  C-1 Intercosmos
#
#                 Orbit Type                      Application  \
# 0                    Lunar            Planetary Observation
# 1                    Lunar            Planetary Observation
# 2                      NaN                       Navigation
# 3                      NaN                Earth Observation
# 4                      NaN                Earth Observation
# ..                     ...                              ...
# 120  LEO (Low Earth Orbit)                Earth Observation
# 121                    NaN                              NaN
# 122                    NaN                              NaN
# 123  LEO (Low Earth Orbit)  Earth Observation, Experimental
# 124                    NaN                     Experimental
#
#                  Remarks                     Mission Name
# 0      Launch successful                        Aditya-L1
# 1      Launch successful                    Chandrayaan-3
# 2      Launch successful                           NVS-01
# 3      Launch successful                           EOS-07
# 4      Launch successful                          Thybolt
# ..                   ...                              ...
# 120    Launch successful           Rohini Satellite RS-D1
# 121    Launch successful            Rohini Satellite RS-1
# 122  Launch unsuccessful  Rohini Technology Payload (RTP)
# 123    Launch successful                       Bhaskara-I
# 124    Launch successful                        Aryabhata
#
# [125 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# SL No              0
# Launch Date        0
# Launch Vehicle     0
# Orbit Type        21
# Application        4
# Remarks            0
# Mission Name       0
# dtype: int64

# %%
df[df['Orbit Type'].isna() | df['Application'].isna()]
# Out:
#      SL No Launch Date              Launch Vehicle  \
# 2      123  2023-05-29     GSLV-F12/NVS-01 Mission
# 3      122  2023-02-10      SSLV-D2/EOS-07 Mission
# 4      121  2022-11-26     PSLV-C54/EOS-06 Mission
# 5      120  2022-11-26     PSLV-C54/EOS-06 Mission
# 6      119  2022-11-26     PSLV-C54/EOS-06 Mission
# 7      118  2022-11-26     PSLV-C54/EOS-06 Mission
# 8      117  2022-11-26     PSLV-C54/EOS-06 Mission
# 9      116  2022-08-07      SSLV-D1/EOS-02 Mission
# 11     114  2022-02-14     PSLV-C52/EOS-04 Mission
# 12     113  2022-02-14     PSLV-C52/EOS-04 Mission
# 21     104  2019-04-01     PSLV-C45/EMISAT MISSION
# 23     102  2019-01-24                    PSLV-C44
# 24     101  2018-12-19  GSLV-F11 / GSAT-7A Mission
# 33      92  2017-08-31   PSLV-C39/IRNSS-1H Mission
# 50      75  2015-09-28   PSLV-C30/AstroSat MISSION
# 53      72  2014-12-18          LVM-3/CARE Mission
# 104     21  1994-05-04                     ASLV-D4
# 108     17  1992-05-20                     ASLV-D3
# 112     13  1988-07-13                     ASLV-D2
# 114     11  1987-03-24                     ASLV-D1
# 121      4  1980-07-18                     SLV-3E2
# 122      3  1979-08-10                     SLV-3E1
# 124      1  1975-04-19             C-1 Intercosmos
#
#                              Orbit Type                      Application  \
# 2                                   NaN                       Navigation
# 3                                   NaN                Earth Observation
# 4                                   NaN                Earth Observation
# 5                                   NaN                Earth Observation
# 6                                   NaN                Earth Observation
# 7                                   NaN                Earth Observation
# 8                                   NaN                Earth Observation
# 9                                   NaN                Earth Observation
# 11                                  NaN                     Experimental
# 12                                  NaN                Earth Observation
# 21   SSPO (Sun Synchronous Polar Orbit)                              NaN
# 23   SSPO (Sun Synchronous Polar Orbit)                              NaN
# 24                                  NaN                    Communication
# 33                                  NaN                       Navigation
# 50                                  NaN                    Space Science
# 53                                  NaN                     Experimental
# 104                                 NaN                     Experimental
# 108                                 NaN                     Experimental
# 112                                 NaN  Earth Observation, Experimental
# 114                                 NaN                     Experimental
# 121                                 NaN                              NaN
# 122                                 NaN                              NaN
# 124                                 NaN                     Experimental
#
#                  Remarks                                       Mission Name
# 2      Launch successful                                             NVS-01
# 3      Launch successful                                             EOS-07
# 4      Launch successful                                            Thybolt
# 5      Launch successful                                            Thybolt
# 6      Launch successful                                              Anand
# 7      Launch successful                                             INS-2B
# 8      Launch successful                                             EOS-06
# 9      Launch successful                                             EOS-02
# 11     Launch successful                                            INS-2TD
# 12     Launch successful                                             EOS-04
# 21     Launch successful                                             EMISAT
# 23     Launch successful                                         Microsat-R
# 24     Launch successful                                            GSAT-7A
# 33   Launch unsuccessful                                           IRNSS-1H
# 50     Launch successful                                           Astrosat
# 53     Launch successful  Crew module Atmospheric Re-entry Experiment (C...
# 104    Launch successful                                           SROSS-C2
# 108    Launch successful                                            SROSS-C
# 112  Launch unsuccessful                                            SROSS-2
# 114  Launch unsuccessful                                            SROSS-1
# 121    Launch successful                              Rohini Satellite RS-1
# 122  Launch unsuccessful                    Rohini Technology Payload (RTP)
# 124    Launch successful                                          Aryabhata

# %%
df_new = df.dropna(subset="Orbit Type")
df_new
# Out:
#      SL No Launch Date                   Launch Vehicle  \
# 0      125  2023-09-02       PSLV-C57/Aditya-L1 Mission
# 1      124  2023-07-14  LVM3 M4 / Chandrayaan-3 Mission
# 10     115  2022-06-23                  Ariane-V(VS257)
# 13     112  2021-08-12        GSLV-F10 / EOS-03 Mission
# 14     111  2020-12-17                  PSLV-C50/CMS-01
# ..     ...         ...                              ...
# 117      8  1982-04-10                            Delta
# 118      7  1981-11-20                  C-1 Intercosmos
# 119      6  1981-06-19                   Ariane -1(V-3)
# 120      5  1981-05-31                          SLV-3D1
# 123      2  1979-06-07                   C-1Intercosmos
#
#                               Orbit Type                      Application  \
# 0                                  Lunar            Planetary Observation
# 1                                  Lunar            Planetary Observation
# 10            GSO (Geosynchronous Orbit)                    Communication
# 13   GTO (Geosynchronous Transfer Orbit)                Earth Observation
# 14            GSO (Geosynchronous Orbit)                    Communication
# ..                                   ...                              ...
# 117           GSO (Geosynchronous Orbit)                    Communication
# 118                LEO (Low Earth Orbit)  Earth Observation, Experimental
# 119           GSO (Geosynchronous Orbit)      Communication, Experimental
# 120                LEO (Low Earth Orbit)                Earth Observation
# 123                LEO (Low Earth Orbit)  Earth Observation, Experimental
#
#                  Remarks            Mission Name
# 0      Launch successful               Aditya-L1
# 1      Launch successful           Chandrayaan-3
# 10     Launch successful                 GSAT-24
# 13   Launch unsuccessful                  EOS-03
# 14     Launch successful                  CMS-01
# ..                   ...                     ...
# 117      Failed in Orbit                INSAT-1A
# 118    Launch successful             Bhaskara-II
# 119    Launch successful                   APPLE
# 120    Launch successful  Rohini Satellite RS-D1
# 123    Launch successful              Bhaskara-I
#
# [104 rows x 7 columns]

# %%
df_new.shape
df_new.head()
df_new
# Out:
#      SL No Launch Date                   Launch Vehicle  \
# 0      125  2023-09-02       PSLV-C57/Aditya-L1 Mission
# 1      124  2023-07-14  LVM3 M4 / Chandrayaan-3 Mission
# 10     115  2022-06-23                  Ariane-V(VS257)
# 13     112  2021-08-12        GSLV-F10 / EOS-03 Mission
# 14     111  2020-12-17                  PSLV-C50/CMS-01
# ..     ...         ...                              ...
# 117      8  1982-04-10                            Delta
# 118      7  1981-11-20                  C-1 Intercosmos
# 119      6  1981-06-19                   Ariane -1(V-3)
# 120      5  1981-05-31                          SLV-3D1
# 123      2  1979-06-07                   C-1Intercosmos
#
#                               Orbit Type                      Application  \
# 0                                  Lunar            Planetary Observation
# 1                                  Lunar            Planetary Observation
# 10            GSO (Geosynchronous Orbit)                    Communication
# 13   GTO (Geosynchronous Transfer Orbit)                Earth Observation
# 14            GSO (Geosynchronous Orbit)                    Communication
# ..                                   ...                              ...
# 117           GSO (Geosynchronous Orbit)                    Communication
# 118                LEO (Low Earth Orbit)  Earth Observation, Experimental
# 119           GSO (Geosynchronous Orbit)      Communication, Experimental
# 120                LEO (Low Earth Orbit)                Earth Observation
# 123                LEO (Low Earth Orbit)  Earth Observation, Experimental
#
#                  Remarks            Mission Name
# 0      Launch successful               Aditya-L1
# 1      Launch successful           Chandrayaan-3
# 10     Launch successful                 GSAT-24
# 13   Launch unsuccessful                  EOS-03
# 14     Launch successful                  CMS-01
# ..                   ...                     ...
# 117      Failed in Orbit                INSAT-1A
# 118    Launch successful             Bhaskara-II
# 119    Launch successful                   APPLE
# 120    Launch successful  Rohini Satellite RS-D1
# 123    Launch successful              Bhaskara-I
#
# [104 rows x 7 columns]

# %%
df[df['Application'].isna()]
# Out:
#      SL No Launch Date           Launch Vehicle  \
# 21     104  2019-04-01  PSLV-C45/EMISAT MISSION
# 23     102  2019-01-24                 PSLV-C44
# 121      4  1980-07-18                  SLV-3E2
# 122      3  1979-08-10                  SLV-3E1
#
#                              Orbit Type Application              Remarks  \
# 21   SSPO (Sun Synchronous Polar Orbit)         NaN    Launch successful
# 23   SSPO (Sun Synchronous Polar Orbit)         NaN    Launch successful
# 121                                 NaN         NaN    Launch successful
# 122                                 NaN         NaN  Launch unsuccessful
#
#                         Mission Name
# 21                            EMISAT
# 23                        Microsat-R
# 121            Rohini Satellite RS-1
# 122  Rohini Technology Payload (RTP)

# %%
df_new2 = df_new.dropna(subset=['Application'])
df_new2
# Out:
#      SL No Launch Date                   Launch Vehicle  \
# 0      125  2023-09-02       PSLV-C57/Aditya-L1 Mission
# 1      124  2023-07-14  LVM3 M4 / Chandrayaan-3 Mission
# 10     115  2022-06-23                  Ariane-V(VS257)
# 13     112  2021-08-12        GSLV-F10 / EOS-03 Mission
# 14     111  2020-12-17                  PSLV-C50/CMS-01
# ..     ...         ...                              ...
# 117      8  1982-04-10                            Delta
# 118      7  1981-11-20                  C-1 Intercosmos
# 119      6  1981-06-19                   Ariane -1(V-3)
# 120      5  1981-05-31                          SLV-3D1
# 123      2  1979-06-07                   C-1Intercosmos
#
#                               Orbit Type                      Application  \
# 0                                  Lunar            Planetary Observation
# 1                                  Lunar            Planetary Observation
# 10            GSO (Geosynchronous Orbit)                    Communication
# 13   GTO (Geosynchronous Transfer Orbit)                Earth Observation
# 14            GSO (Geosynchronous Orbit)                    Communication
# ..                                   ...                              ...
# 117           GSO (Geosynchronous Orbit)                    Communication
# 118                LEO (Low Earth Orbit)  Earth Observation, Experimental
# 119           GSO (Geosynchronous Orbit)      Communication, Experimental
# 120                LEO (Low Earth Orbit)                Earth Observation
# 123                LEO (Low Earth Orbit)  Earth Observation, Experimental
#
#                  Remarks            Mission Name
# 0      Launch successful               Aditya-L1
# 1      Launch successful           Chandrayaan-3
# 10     Launch successful                 GSAT-24
# 13   Launch unsuccessful                  EOS-03
# 14     Launch successful                  CMS-01
# ..                   ...                     ...
# 117      Failed in Orbit                INSAT-1A
# 118    Launch successful             Bhaskara-II
# 119    Launch successful                   APPLE
# 120    Launch successful  Rohini Satellite RS-D1
# 123    Launch successful              Bhaskara-I
#
# [102 rows x 7 columns]

# %%
df_new2.describe(include='all')
# Out:
#              SL No                    Launch Date  \
# count   102.000000                            102
# unique         NaN                            NaN
# top            NaN                            NaN
# freq           NaN                            NaN
# mean     59.568627  2008-05-03 20:56:28.235294208
# min       2.000000            1979-06-07 00:00:00
# 25%      33.250000            2002-03-22 18:00:00
# 50%      58.500000            2011-06-17 12:00:00
# 75%      85.750000            2017-02-15 00:00:00
# max     125.000000            2023-09-02 00:00:00
# std      32.265455                            NaN
#
#                                  Launch Vehicle                  Orbit Type  \
# count                                       102                         102
# unique                                       92                           7
# top     PSLV-C37 / Cartosat -2 Series Satellite  GSO (Geosynchronous Orbit)
# freq                                          3                          42
# mean                                        NaN                         NaN
# min                                         NaN                         NaN
# 25%                                         NaN                         NaN
# 50%                                         NaN                         NaN
# 75%                                         NaN                         NaN
# max                                         NaN                         NaN
# std                                         NaN                         NaN
#
#           Application            Remarks                 Mission Name
# count             102                102                          102
# unique             14                  5                          101
# top     Communication  Launch successful  Cartosat-2 Series Satellite
# freq               37                 93                            2
# mean              NaN                NaN                          NaN
# min               NaN                NaN                          NaN
# 25%               NaN                NaN                          NaN
# 50%               NaN                NaN                          NaN
# 75%               NaN                NaN                          NaN
# max               NaN                NaN                          NaN
# std               NaN                NaN                          NaN

# %%
launch_years = df_new2['Launch Date'].dt.year
launch_data = launch_years.value_counts().sort_index()
launch_data
# Out:
# Launch Date
# 1979    1
# 1981    3
# 1982    1
# 1983    2
# 1988    2
# 1990    1
# 1991    1
# 1992    1
# 1993    2
# 1994    1
# 1995    2
# 1996    1
# 1997    2
# 1999    2
# 2000    1
# 2001    2
# 2002    2
# 2003    4
# 2004    1
# 2005    3
# 2006    1
# 2007    4
# 2008    3
# 2009    2
# 2010    3
# 2011    5
# 2012    2
# 2013    5
# 2014    4
# 2015    3
# 2016    8
# 2017    7
# 2018    8
# 2019    5
# 2020    3
# 2021    1
# 2022    1
# 2023    2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
def missions_by_applications(df):
    plt.clf()
    application_data = df_new2['Application'].value_counts()
    plt.figure(figsize=(8,8))
    application_data.plot(kind= 'pie', autopct='%1.0f%%')
    plt.title('ISRO (Indian Space Research Organization) Satelite Purposes from 1979-2023')
    plt.show()
    plt.pause(0.001)

# %%
def count_applications(df):
    return df['Application'].value_counts()
count_applications(df_new2)
# Out:
# Application
# Communication                                        37
# Earth Observation                                    28
# Navigation                                            8
# Planetary Observation                                 5
# Experimental                                          5
# Disaster Management System, Earth Observation         3
# Climate & Environment, Earth Observation              3
# Communication, Navigation                             3
# Climate & Environment, Communication                  3
# Climate & Environment, Disaster Management System     2
# Earth Observation, Experimental                       2
# Climate & Environment                                 1
# Student Satellite                                     1
# Communication, Experimental                           1
# Name: count, dtype: int64

# %%
df_new2['Launch Date'].head()
# Out:
# 0    2023-09-02
# 1    2023-07-14
# 10   2022-06-23
# 13   2021-08-12
# 14   2020-12-17
# Name: Launch Date, dtype: datetime64[ns]

# %%
df_new2 = df_new2.copy()
df_new2['Year'] = df_new2['Launch Date'].dt.year
df_new2
# Out:
#      SL No Launch Date                   Launch Vehicle  \
# 0      125  2023-09-02       PSLV-C57/Aditya-L1 Mission
# 1      124  2023-07-14  LVM3 M4 / Chandrayaan-3 Mission
# 10     115  2022-06-23                  Ariane-V(VS257)
# 13     112  2021-08-12        GSLV-F10 / EOS-03 Mission
# 14     111  2020-12-17                  PSLV-C50/CMS-01
# ..     ...         ...                              ...
# 117      8  1982-04-10                            Delta
# 118      7  1981-11-20                  C-1 Intercosmos
# 119      6  1981-06-19                   Ariane -1(V-3)
# 120      5  1981-05-31                          SLV-3D1
# 123      2  1979-06-07                   C-1Intercosmos
#
#                               Orbit Type                      Application  \
# 0                                  Lunar            Planetary Observation
# 1                                  Lunar            Planetary Observation
# 10            GSO (Geosynchronous Orbit)                    Communication
# 13   GTO (Geosynchronous Transfer Orbit)                Earth Observation
# 14            GSO (Geosynchronous Orbit)                    Communication
# ..                                   ...                              ...
# 117           GSO (Geosynchronous Orbit)                    Communication
# 118                LEO (Low Earth Orbit)  Earth Observation, Experimental
# 119           GSO (Geosynchronous Orbit)      Communication, Experimental
# 120                LEO (Low Earth Orbit)                Earth Observation
# 123                LEO (Low Earth Orbit)  Earth Observation, Experimental
#
#                  Remarks            Mission Name  Year
# 0      Launch successful               Aditya-L1  2023
# 1      Launch successful           Chandrayaan-3  2023
# 10     Launch successful                 GSAT-24  2022
# 13   Launch unsuccessful                  EOS-03  2021
# 14     Launch successful                  CMS-01  2020
# ..                   ...                     ...   ...
# 117      Failed in Orbit                INSAT-1A  1982
# 118    Launch successful             Bhaskara-II  1981
# 119    Launch successful                   APPLE  1981
# 120    Launch successful  Rohini Satellite RS-D1  1981
# 123    Launch successful              Bhaskara-I  1979
#
# [102 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
def missions_per_year(df):
    plt.clf()
    mission_annual_count = df['Year'].value_counts().sort_index()
    mission_annual_count.plot(kind='bar')
    plt.xlabel('Year')
    plt.ylabel('Launch Count')
    plt.title('ISRO Missions Per Year')
    plt.show()
    plt.pause(0.001)

# %%
import matplotlib.pyplot as plt
def missions_by_vehicle(df):
    plt.clf()
    vehicle_number = df['Launch Vehicle'].value_counts()
    plt.figure(figsize=(11,6))
    vehicle_number.plot(kind= 'bar')
    plt.title('ISRO Missions by Launch Vehicle Type')
    plt.show()
    plt.pause(0.001)

# %%
import matplotlib.pyplot as plt
def missions_by_orbit(df):
    plt.clf()
    orbit_number = df_new2['Orbit Type'].value_counts()
    plt.figure(figsize=(11,6))
    orbit_number.plot(kind='barh')
    plt.xlabel('Orbit Type')
    plt.ylabel('Count')
    plt.title('ISRO (Indian Space Research Organization) Mission Launches by Orbit Type, 1979-2023')
    plt.show()
    plt.pause(0.001)

# %%
def show_menu():
    print('---ISRO (Indian Space Research Organization) Mission Analysis, 1979-2023---')
    print('\n---Select from the menu below---')
    print('Option 1: Missions by Year')
    print('Option 2: Missions by Purpose')
    print('Option 3: Missions by Launch Vehicle')
    print('Option 4: Missions by Orbit Type')
    print('Option 5: EXIT')
show_menu()
# Out:
# ---ISRO (Indian Space Research Organization) Mission Analysis, 1979-2023---
#
# ---Select from the menu below---
# Option 1: Missions by Year
# Option 2: Missions by Purpose
# Option 3: Missions by Launch Vehicle
# Option 4: Missions by Orbit Type
# Option 5: EXIT

# %%
import matplotlib.pyplot as plt
def activate():
    while True:
        show_menu()
        selection = input('What do you want to analyze today? (Enter a number, 1-5) ')

        if selection == '1':
            missions_per_year(df_new2)
        elif selection == '2':
            missions_by_applications(df_new2)
        elif selection == '3':
            missions_by_vehicle(df_new2)
            plt.show
        elif selection == '4':
            missions_by_orbit(df_new2)
        elif selection == '5':
            print('Thanks for learning about ISRO!')
            break
        else:
            print('Please enter only a number between 1-5, and nothing else. Example: 5')
            
activate()
# Out:
# ---ISRO (Indian Space Research Organization) Mission Analysis, 1979-2023---
#
# ---Select from the menu below---
# Option 1: Missions by Year
# Option 2: Missions by Purpose
# Option 3: Missions by Launch Vehicle
# Option 4: Missions by Orbit Type
# Option 5: EXIT
# What do you want to analyze today? (Enter a number, 1-5)  3
# ---ISRO (Indian Space Research Organization) Mission Analysis, 1979-2023---
#
# ---Select from the menu below---
# Option 1: Missions by Year
# Option 2: Missions by Purpose
# Option 3: Missions by Launch Vehicle
# Option 4: Missions by Orbit Type
# Option 5: EXIT
# What do you want to analyze today? (Enter a number, 1-5)  2
# ---ISRO (Indian Space Research Organization) Mission Analysis, 1979-2023---
#
# ---Select from the menu below---
# Option 1: Missions by Year
# Option 2: Missions by Purpose
# Option 3: Missions by Launch Vehicle
# Option 4: Missions by Orbit Type
# Option 5: EXIT
# What do you want to analyze today? (Enter a number, 1-5)  4
# ---ISRO (Indian Space Research Organization) Mission Analysis, 1979-2023---
#
# ---Select from the menu below---
# Option 1: Missions by Year
# Option 2: Missions by Purpose
# Option 3: Missions by Launch Vehicle
# Option 4: Missions by Orbit Type
# Option 5: EXIT
# What do you want to analyze today? (Enter a number, 1-5)  1
# ---ISRO (Indian Space Research Organization) Mission Analysis, 1979-2023---
#
# ---Select from the menu below---
# Option 1: Missions by Year
# Option 2: Missions by Purpose
# Option 3: Missions by Launch Vehicle
# Option 4: Missions by Orbit Type
# Option 5: EXIT
# What do you want to analyze today? (Enter a number, 1-5)  9
# Please enter only a number between 1-5, and nothing else. Example: 5
# ---ISRO (Indian Space Research Organization) Mission Analysis, 1979-2023---
#
# ---Select from the menu below---
# Option 1: Missions by Year
# Option 2: Missions by Purpose
# Option 3: Missions by Launch Vehicle
# Option 4: Missions by Orbit Type
# Option 5: EXIT
# What do you want to analyze today? (Enter a number, 1-5)  5
# Thanks for learning about ISRO!
